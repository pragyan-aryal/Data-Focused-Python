# %%
import pandas as pd
import re

# %%
# Read a Parquet file
df = pd.read_parquet('../Data/Indeed/Indeed_Data.parquet')
# Now 'df' is a DataFrame containing the data from the Parquet file

# %%
# Define a regular expression pattern to match dollar sign followed by numbers
pattern = r'\$([\d,]+(?:\.\d+)?)\s*(?:- \$([\d,]+(?:\.\d+)?))?'

# Create new columns for min and max salaries
df['MinSalary'] = None
df['MaxSalary'] = None

# Iterate over the rows of the 'Salary' column
for index, row in df.iterrows():
    line = row['Salary']
    if line is not None:
        match = re.search(pattern, str(line))
        if match:
            min_salary, max_salary = match.groups()
            df.at[index, 'MinSalary'] = float(min_salary.replace(',', '')) if min_salary else None
            df.at[index, 'MaxSalary'] = float(max_salary.replace(',', '')) if max_salary else None

df
# Out:
#                     Key                                Company  \
# 0      a9832db271ef3fc4  US Office of the Secretary of Defense
# 1      7f4db33d08d5c611                    Booz Allen Hamilton
# 2      0636da957769d80b                      PRYSMIANGROUP.COM
# 3      f2d5e432940c9f42                                   NYCM
# 4      ec9509f4c611785a               Johns Hopkins University
# ...                 ...                                    ...
# 23272  072bf35ffdd8645d  General Dynamics Mission Systems, Inc
# 23273  789179d9fd5c1d65  Metropolitan Transportation Authority
# 23274  f9785443a3551b34           MPIRE Technology Group, Inc.
# 23275  5f15c9ca93989af6               Talentech Consulting LLC
# 23276  ea2bf756466c7fb6                          The DEI Group
#
#                                           Position Category Experience_Level  \
# 0                      Operations Research Analyst       BA      ENTRY_LEVEL
# 1                         IT Business Analyst, Mid       BA      ENTRY_LEVEL
# 2           SAP Intercompany Business Analyst (FT)       BA      ENTRY_LEVEL
# 3                   Business Data Analyst (Hybrid)       BA      ENTRY_LEVEL
# 4                    Investment Operations Analyst       BA      ENTRY_LEVEL
# ...                                            ...      ...              ...
# 23272                     Senior Software Engineer       SE     SENIOR_LEVEL
# 23273  Application Developer 1-5 (TCU Represented)       SE     SENIOR_LEVEL
# 23274                        Senior Cloud Engineer       SE     SENIOR_LEVEL
# 23275                       Statistical Programmer       SE     SENIOR_LEVEL
# 23276              Sr. Software Engineer/Architect       SE     SENIOR_LEVEL
#
#                                  Salary  \
# 0            $155,700 - $183,500 a year
# 1             $52,100 - $119,000 a year
# 2                                  None
# 3              $35,057 - $63,103 a year
# 4             $84,700 - $148,300 a year
# ...                                 ...
# 23272        $146,048 - $162,000 a year
# 23273          $57,100 - $81,572 a year
# 23274  $117,161.90 - $141,098.20 a year
# 23275                              None
# 23276        $100,000 - $130,000 a year
#
#                                              Description  \
# 0      DutiesThis is a Direct Hire Public Notice, und...
# 1      Job Description         Location:             ...
# 2        Prysmian is a global cable manufacturer with...
# 3      The Business Data Analyst (Hybrid) will perfor...
# 4      The Johns Hopkins University, one of the world...
# ...                                                  ...
# 23272   Basic Qualifications :     Requires a Bachelo...
# 23273  Description Job Title: Application Developer A...
# 23274  MPIRE Technology Group, Inc is seeking several...
# 23275  We are looking for two experienced statistical...
# 23276  Senior Software Engineer works as part of an a...
#
#                                                 Benefits   Work_Commute  \
# 0                                                     []        On-Site
# 1      ['401(k)', '401(k) matching', 'Flexible schedu...  Hybrid Remote
# 2                                                     []        On-Site
# 3                                                     []        On-Site
# 4                                                     []  Hybrid Remote
# ...                                                  ...            ...
# 23272  ['401(k)', '401(k) matching', 'Flexible schedu...  Hybrid Remote
# 23273                                                 []        On-Site
# 23274  ['Dental insurance', 'Employee assistance prog...  Hybrid Remote
# 23275  ['401(k)', 'Dental insurance', 'Flexible spend...        On-Site
# 23276                                                 []        On-Site
#
#                                      Clean_location   latitude  longitude  \
# 0                                     Arlington, VA  38.864458 -77.099638
# 1                                       Atlanta, GA  33.769805 -84.414581
# 2                              Highland Heights, KY  39.037110 -84.456707
# 3                                Edmeston, NY 13335  42.702260 -75.248224
# 4                               Baltimore, MD 21211  39.319732 -76.649533
# ...                                             ...        ...        ...
# 23272                         Bloomington, MN 55431  44.827321 -93.317043
# 23273  New York, NY 10004 (Financial District area)  40.688873 -74.018213
# 23274                          Alexandria, VA 22314  38.804840 -77.046920
# 23275                                        Remote        NaN        NaN
# 23276                            Columbia, MD 21045  39.199038 -76.841517
#
#       region_code     region              county          locality  \
# 0              VA   Virginia    Arlington County         Arlington
# 1              GA    Georgia       Fulton County           Atlanta
# 2              KY   Kentucky     Campbell County  Highland Heights
# 3              NY   New York       Otsego County          Edmeston
# 4              MD   Maryland   City of Baltimore         Baltimore
# ...           ...        ...                 ...               ...
# 23272          MN  Minnesota     Hennepin County       Bloomington
# 23273          NY   New York        Kings County          New York
# 23274          VA   Virginia  City of Alexandria        Alexandria
# 23275        None       None                None              None
# 23276          MD   Maryland       Howard County          Columbia
#
#       country_code MinSalary MaxSalary
# 0              USA  155700.0  183500.0
# 1              USA   52100.0  119000.0
# 2              USA      None      None
# 3              USA   35057.0   63103.0
# 4              USA   84700.0  148300.0
# ...            ...       ...       ...
# 23272          USA  146048.0  162000.0
# 23273          USA   57100.0   81572.0
# 23274          USA  117161.9  141098.2
# 23275         None      None      None
# 23276          USA  100000.0  130000.0
#
# [23277 rows x 19 columns]

# %%
pattern_hour_range = r'\$([\d,]+(?:\.\d+)?)\s*-\s*\$([\d,]+(?:\.\d+)?)\s*an hour'
pattern_hour_single = r'\$([\d,]+(?:\.\d+)?)\s*an hour'
for index, row in df.iterrows():
    line = row['Salary']
    if line is not None:
        # Check for hourly rates specified as a range
        match_hourly_range = re.search(pattern_hour_range, str(line))
        if match_hourly_range:
            min_hourly, max_hourly = match_hourly_range.groups()
            min_hourly = float(min_hourly.replace(',', '')) if min_hourly else None
            max_hourly = float(max_hourly.replace(',', '')) if max_hourly else None
            df.at[index, 'MinSalary'] = min_hourly * 1920
            df.at[index, 'MaxSalary'] = max_hourly * 1920 if max_hourly else None
        else:
            # Check for hourly rates specified as a single value
            match_hourly_single = re.search(pattern_hour_single, str(line))
            if match_hourly_single:
                min_hourly = match_hourly_single.group(1)
                min_hourly = float(min_hourly.replace(',', '')) if min_hourly else None
                df.at[index, 'MinSalary'] = min_hourly * 1920

# Print the updated DataFrame
df
# Out:
#                     Key                                Company  \
# 0      a9832db271ef3fc4  US Office of the Secretary of Defense
# 1      7f4db33d08d5c611                    Booz Allen Hamilton
# 2      0636da957769d80b                      PRYSMIANGROUP.COM
# 3      f2d5e432940c9f42                                   NYCM
# 4      ec9509f4c611785a               Johns Hopkins University
# ...                 ...                                    ...
# 23272  072bf35ffdd8645d  General Dynamics Mission Systems, Inc
# 23273  789179d9fd5c1d65  Metropolitan Transportation Authority
# 23274  f9785443a3551b34           MPIRE Technology Group, Inc.
# 23275  5f15c9ca93989af6               Talentech Consulting LLC
# 23276  ea2bf756466c7fb6                          The DEI Group
#
#                                           Position Category Experience_Level  \
# 0                      Operations Research Analyst       BA      ENTRY_LEVEL
# 1                         IT Business Analyst, Mid       BA      ENTRY_LEVEL
# 2           SAP Intercompany Business Analyst (FT)       BA      ENTRY_LEVEL
# 3                   Business Data Analyst (Hybrid)       BA      ENTRY_LEVEL
# 4                    Investment Operations Analyst       BA      ENTRY_LEVEL
# ...                                            ...      ...              ...
# 23272                     Senior Software Engineer       SE     SENIOR_LEVEL
# 23273  Application Developer 1-5 (TCU Represented)       SE     SENIOR_LEVEL
# 23274                        Senior Cloud Engineer       SE     SENIOR_LEVEL
# 23275                       Statistical Programmer       SE     SENIOR_LEVEL
# 23276              Sr. Software Engineer/Architect       SE     SENIOR_LEVEL
#
#                                  Salary  \
# 0            $155,700 - $183,500 a year
# 1             $52,100 - $119,000 a year
# 2                                  None
# 3              $35,057 - $63,103 a year
# 4             $84,700 - $148,300 a year
# ...                                 ...
# 23272        $146,048 - $162,000 a year
# 23273          $57,100 - $81,572 a year
# 23274  $117,161.90 - $141,098.20 a year
# 23275                              None
# 23276        $100,000 - $130,000 a year
#
#                                              Description  \
# 0      DutiesThis is a Direct Hire Public Notice, und...
# 1      Job Description         Location:             ...
# 2        Prysmian is a global cable manufacturer with...
# 3      The Business Data Analyst (Hybrid) will perfor...
# 4      The Johns Hopkins University, one of the world...
# ...                                                  ...
# 23272   Basic Qualifications :     Requires a Bachelo...
# 23273  Description Job Title: Application Developer A...
# 23274  MPIRE Technology Group, Inc is seeking several...
# 23275  We are looking for two experienced statistical...
# 23276  Senior Software Engineer works as part of an a...
#
#                                                 Benefits   Work_Commute  \
# 0                                                     []        On-Site
# 1      ['401(k)', '401(k) matching', 'Flexible schedu...  Hybrid Remote
# 2                                                     []        On-Site
# 3                                                     []        On-Site
# 4                                                     []  Hybrid Remote
# ...                                                  ...            ...
# 23272  ['401(k)', '401(k) matching', 'Flexible schedu...  Hybrid Remote
# 23273                                                 []        On-Site
# 23274  ['Dental insurance', 'Employee assistance prog...  Hybrid Remote
# 23275  ['401(k)', 'Dental insurance', 'Flexible spend...        On-Site
# 23276                                                 []        On-Site
#
#                                      Clean_location   latitude  longitude  \
# 0                                     Arlington, VA  38.864458 -77.099638
# 1                                       Atlanta, GA  33.769805 -84.414581
# 2                              Highland Heights, KY  39.037110 -84.456707
# 3                                Edmeston, NY 13335  42.702260 -75.248224
# 4                               Baltimore, MD 21211  39.319732 -76.649533
# ...                                             ...        ...        ...
# 23272                         Bloomington, MN 55431  44.827321 -93.317043
# 23273  New York, NY 10004 (Financial District area)  40.688873 -74.018213
# 23274                          Alexandria, VA 22314  38.804840 -77.046920
# 23275                                        Remote        NaN        NaN
# 23276                            Columbia, MD 21045  39.199038 -76.841517
#
#       region_code     region              county          locality  \
# 0              VA   Virginia    Arlington County         Arlington
# 1              GA    Georgia       Fulton County           Atlanta
# 2              KY   Kentucky     Campbell County  Highland Heights
# 3              NY   New York       Otsego County          Edmeston
# 4              MD   Maryland   City of Baltimore         Baltimore
# ...           ...        ...                 ...               ...
# 23272          MN  Minnesota     Hennepin County       Bloomington
# 23273          NY   New York        Kings County          New York
# 23274          VA   Virginia  City of Alexandria        Alexandria
# 23275        None       None                None              None
# 23276          MD   Maryland       Howard County          Columbia
#
#       country_code MinSalary MaxSalary
# 0              USA  155700.0  183500.0
# 1              USA   52100.0  119000.0
# 2              USA      None      None
# 3              USA   35057.0   63103.0
# 4              USA   84700.0  148300.0
# ...            ...       ...       ...
# 23272          USA  146048.0  162000.0
# 23273          USA   57100.0   81572.0
# 23274          USA  117161.9  141098.2
# 23275         None      None      None
# 23276          USA  100000.0  130000.0
#
# [23277 rows x 19 columns]

# %%
pattern_month = r'(?:From\s*)?\$([\d,]+(?:\.\d+)?)\s*(?:- \$([\d,]+(?:\.\d+)?))?\s*a\s*month'
# Separate loop for updating monthly rates
for index, row in df.iterrows():
    line = row['Salary']
    if line is not None:
        match_monthly = re.search(pattern_month, str(line))
        if match_monthly:
            min_monthly, max_monthly = match_monthly.groups()
            min_monthly = float(min_monthly.replace(',', '')) if min_monthly else None
            max_monthly = float(max_monthly.replace(',', '')) if max_monthly else None
            df.at[index, 'MinSalary'] = min_monthly * 12
            df.at[index, 'MaxSalary'] = max_monthly * 12 if max_monthly else None  # No defined max for monthly rates

# Print the updated DataFrame
df
# Out:
#                     Key                                Company  \
# 0      a9832db271ef3fc4  US Office of the Secretary of Defense
# 1      7f4db33d08d5c611                    Booz Allen Hamilton
# 2      0636da957769d80b                      PRYSMIANGROUP.COM
# 3      f2d5e432940c9f42                                   NYCM
# 4      ec9509f4c611785a               Johns Hopkins University
# ...                 ...                                    ...
# 23272  072bf35ffdd8645d  General Dynamics Mission Systems, Inc
# 23273  789179d9fd5c1d65  Metropolitan Transportation Authority
# 23274  f9785443a3551b34           MPIRE Technology Group, Inc.
# 23275  5f15c9ca93989af6               Talentech Consulting LLC
# 23276  ea2bf756466c7fb6                          The DEI Group
#
#                                           Position Category Experience_Level  \
# 0                      Operations Research Analyst       BA      ENTRY_LEVEL
# 1                         IT Business Analyst, Mid       BA      ENTRY_LEVEL
# 2           SAP Intercompany Business Analyst (FT)       BA      ENTRY_LEVEL
# 3                   Business Data Analyst (Hybrid)       BA      ENTRY_LEVEL
# 4                    Investment Operations Analyst       BA      ENTRY_LEVEL
# ...                                            ...      ...              ...
# 23272                     Senior Software Engineer       SE     SENIOR_LEVEL
# 23273  Application Developer 1-5 (TCU Represented)       SE     SENIOR_LEVEL
# 23274                        Senior Cloud Engineer       SE     SENIOR_LEVEL
# 23275                       Statistical Programmer       SE     SENIOR_LEVEL
# 23276              Sr. Software Engineer/Architect       SE     SENIOR_LEVEL
#
#                                  Salary  \
# 0            $155,700 - $183,500 a year
# 1             $52,100 - $119,000 a year
# 2                                  None
# 3              $35,057 - $63,103 a year
# 4             $84,700 - $148,300 a year
# ...                                 ...
# 23272        $146,048 - $162,000 a year
# 23273          $57,100 - $81,572 a year
# 23274  $117,161.90 - $141,098.20 a year
# 23275                              None
# 23276        $100,000 - $130,000 a year
#
#                                              Description  \
# 0      DutiesThis is a Direct Hire Public Notice, und...
# 1      Job Description         Location:             ...
# 2        Prysmian is a global cable manufacturer with...
# 3      The Business Data Analyst (Hybrid) will perfor...
# 4      The Johns Hopkins University, one of the world...
# ...                                                  ...
# 23272   Basic Qualifications :     Requires a Bachelo...
# 23273  Description Job Title: Application Developer A...
# 23274  MPIRE Technology Group, Inc is seeking several...
# 23275  We are looking for two experienced statistical...
# 23276  Senior Software Engineer works as part of an a...
#
#                                                 Benefits   Work_Commute  \
# 0                                                     []        On-Site
# 1      ['401(k)', '401(k) matching', 'Flexible schedu...  Hybrid Remote
# 2                                                     []        On-Site
# 3                                                     []        On-Site
# 4                                                     []  Hybrid Remote
# ...                                                  ...            ...
# 23272  ['401(k)', '401(k) matching', 'Flexible schedu...  Hybrid Remote
# 23273                                                 []        On-Site
# 23274  ['Dental insurance', 'Employee assistance prog...  Hybrid Remote
# 23275  ['401(k)', 'Dental insurance', 'Flexible spend...        On-Site
# 23276                                                 []        On-Site
#
#                                      Clean_location   latitude  longitude  \
# 0                                     Arlington, VA  38.864458 -77.099638
# 1                                       Atlanta, GA  33.769805 -84.414581
# 2                              Highland Heights, KY  39.037110 -84.456707
# 3                                Edmeston, NY 13335  42.702260 -75.248224
# 4                               Baltimore, MD 21211  39.319732 -76.649533
# ...                                             ...        ...        ...
# 23272                         Bloomington, MN 55431  44.827321 -93.317043
# 23273  New York, NY 10004 (Financial District area)  40.688873 -74.018213
# 23274                          Alexandria, VA 22314  38.804840 -77.046920
# 23275                                        Remote        NaN        NaN
# 23276                            Columbia, MD 21045  39.199038 -76.841517
#
#       region_code     region              county          locality  \
# 0              VA   Virginia    Arlington County         Arlington
# 1              GA    Georgia       Fulton County           Atlanta
# 2              KY   Kentucky     Campbell County  Highland Heights
# 3              NY   New York       Otsego County          Edmeston
# 4              MD   Maryland   City of Baltimore         Baltimore
# ...           ...        ...                 ...               ...
# 23272          MN  Minnesota     Hennepin County       Bloomington
# 23273          NY   New York        Kings County          New York
# 23274          VA   Virginia  City of Alexandria        Alexandria
# 23275        None       None                None              None
# 23276          MD   Maryland       Howard County          Columbia
#
#       country_code MinSalary MaxSalary
# 0              USA  155700.0  183500.0
# 1              USA   52100.0  119000.0
# 2              USA      None      None
# 3              USA   35057.0   63103.0
# 4              USA   84700.0  148300.0
# ...            ...       ...       ...
# 23272          USA  146048.0  162000.0
# 23273          USA   57100.0   81572.0
# 23274          USA  117161.9  141098.2
# 23275         None      None      None
# 23276          USA  100000.0  130000.0
#
# [23277 rows x 19 columns]

# %%
df.to_parquet('../Data/Indeed/Indeed_Data.parquet')
